# %% [markdown]
# ### 1.What is Exploratory Data Analysis?
#  Exploratory Data Analysis is an approach to
# analyse the datasets to summarize their
# main characteristics in form of visual
# methods.
# 2.EDA is nothing but an data exploration
# technique to understand various aspects of
# the data.
# 3.The main aim of EDA is to obtain confidence
# in a data to an extent where we are ready to
# engage a machine learning model.'''

# %% [markdown]
# ### 2.Why EDA is important?

# %% [markdown]
# EDA is important to analyse the data it’s a
# first steps in data analysis process.
# EDA give a basic idea to understand the data
# and make sense of the data to figure out the
# question you need to ask and find out the
# best way to manipulate the dataset to get
# the answer of your question.

# %% [markdown]
# ### 1. Descriptive Statistics
# ### 2. Data Visualization:
# ### 3. Handling Missing Data
# ### 4. Data Cleaning
#     i    leanin

# %%
print('AMAZON PRIME DATASET')
from IPython.display import Image
image_path = r"C:\Users\Rohith\Desktop\prime.jpeg"
Image(filename=image_path, width=400,height=40)
# Out:
# AMAZON PRIME DATASET

# %%
# import required librearies for eda technices
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
# %matplotlib inline
import missingno

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r'C:\Users\Rohith\Desktop\amazon dashboard.csv')

# %%
df.head()
# Out:
#   show_id   type                 title        director  \
# 0      s1  Movie   The Grand Seduction    Don McKellar
# 1      s2  Movie  Take Care Good Night    Girish Joshi
# 2      s3  Movie  Secrets of Deception     Josh Webber
# 3      s4  Movie    Pink: Staying True  Sonia Anderson
# 4      s5  Movie         Monster Maker    Giles Foster
#
#                                                 cast         country  \
# 0     Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# 1   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar           India
# 2  Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...   United States
# 3  Interviews with: Pink, Adele, Beyoncé, Britney...   United States
# 4  Harry Dean Stanton, Kieran O'Brien, George Cos...  United Kingdom
#
#        date_added  release_year rating duration                listed_in  \
# 0  March 30, 2021          2014    NaN  113 min            Comedy, Drama
# ...

# %%
df.shape
# Out:
# (9668, 12)

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9668 entries, 0 to 9667
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       9668 non-null   object
#  1   type          9668 non-null   object
#  2   title         9668 non-null   object
#  3   director      7585 non-null   object
#  4   cast          8435 non-null   object
#  5   country       672 non-null    object
#  6   date_added    155 non-null    object
#  7   release_year  9668 non-null   int64
#  8   rating        9331 non-null   object
#  9   duration      9668 non-null   object
#  10  listed_in     9668 non-null   object
#  11  description   9668 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 906.5+ KB

# %%
print(df.isnull().sum())
# Out:
# show_id            0
# type               0
# title              0
# director        2083
# cast            1233
# country         8996
# date_added      9513
# release_year       0
# rating           337
# duration           0
# listed_in          0
# description        0
# dtype: int64

# %%
missingno.matrix(df)
# Out:
# <Axes: >

# %%
# from the above axis we can clearly see that 
# there are many missing values present in the dataset

# %%
df.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
df.describe().T # we only get the 1 column because it is the only int datatype
# Out:
#                count         mean        std     min     25%     50%     75%  \
# release_year  9668.0  2008.341849  18.922482  1920.0  2007.0  2016.0  2019.0
#
#                  max
# release_year  2021.0

# %%
# Histogram of Release Year
plt.figure(figsize=(10, 6))
sb.histplot(df['release_year'], bins=20, kde=True)
plt.title('Distribution of Release Year')
plt.xlabel('Release Year')
plt.ylabel('Frequency')
plt.show()

# %%
# Countplot of Ratings
plt.figure(figsize=(10, 6))
sb.countplot(data=df, x='rating')
plt.title('Count of Ratings')
plt.xlabel('Rating')
plt.ylabel('Count')
plt.show()

# %%
# Histogram of a numerical column (e.g., 'age')
plt.figure(figsize=(10, 6))
plt.hist(df['duration'], bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of duration')
plt.xlabel('duration')
plt.ylabel('Frequency')
plt.show()

# %%
# Data Visualization (example: countplot of type)
plt.figure(figsize=(8, 6))
df['type'].value_counts().plot(kind='bar', color='salmon')
plt.title('Count of Movies vs TV Shows')
plt.xlabel('Type')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.show()

# %%
# Data Visualization (example: countplot of country)
plt.figure(figsize=(12, 8))
df['rating'].value_counts().head(10).plot(kind='barh', color='b')
plt.title('Top 10 Countries with Most Content')
plt.xlabel('Count')
plt.ylabel('rating')
plt.gca().invert_yaxis()
plt.show()

# %%
# Data Visualization (example: countplot of country)
plt.figure(figsize=(12, 8))
df['country'].value_counts().head(10).plot(kind='barh', color='lightgreen')
plt.title('Top 10 Countries with Most Content')
plt.xlabel('Count')
plt.ylabel('Country')
plt.gca().invert_yaxis()
plt.show()

# %%
data=df.groupby(df['country']).sum()
print(data)
# Out:
#                                                                   show_id  \
# country
# Afghanistan, France                                                 s5706
# Australia                                            s2181s5431s7935s8120
# Australia, Colombia, United Kingdom                                 s5813
# Australia, United States, Germany                                   s4452
# Austria                                                             s6574
# ...                                                                   ...
# United States, United Arab Emirates                                 s4822
# United States, United Kingdom              s3099s3406s8333s8907s9375s9376
# United States, United Kingdom, Canada                                s547
# United States, United Kingdom, Germany                               s262
# United States, United Kingdom, Kazakhstan                           s7043
#
# ...

# %%
plt.figure(figsize=(12, 8))
countries = df['country'].value_counts().head(7)  # Get the top 10 countries with most content
plt.barh(countries.index, countries, color='lightgreen')
plt.title('Top 10 Countries with Most Content')
plt.xlabel('Count')
plt.ylabel('Country')
plt.gca().invert_yaxis()
plt.show()

# %%
countries.index
# Out:
# Index(['United States', 'India', 'United Kingdom', 'Canada',
#        'United Kingdom, United States', 'Spain', 'Italy'],
#       dtype='object', name='country')

# %%
# Data Visualization (example: boxplot of duration)
plt.figure(figsize=(10, 6))
df['duration'] = df['duration'].str.extract('(\d+)').astype(float) # Extract numerical values from duration
plt.boxplot(df['duration'])
plt.title('Boxplot of Duration')
plt.ylabel('Duration (min)')
plt.grid(True)
plt.show()

# %%
 #Data Visualization (example: pie chart of ratings)
plt.figure(figsize=(15, 9))
df['rating'].value_counts().plot(kind='pie', autopct='%1.1f%%', colors=['lightblue', 'lightgreen', 'lightcoral', 'lightskyblue'])
plt.title('Distribution of Ratings')
plt.ylabel('')
plt.show()

# %%
# Drop rows with missing values in the 'cast' column
df.dropna(subset=['cast'], inplace=True)

# Convert 'cast' column to string
df['cast'] = df['cast'].astype(str)

# Data Visualization (word cloud of cast)
from wordcloud import WordCloud

plt.figure(figsize=(10, 8))
wordcloud = WordCloud(background_color='black').generate(' '.join(df['cast']))
plt.imshow(wordcloud, interpolation='bilinear')
plt.title('Word Cloud of Cast')
plt.axis('off')
plt.show()
